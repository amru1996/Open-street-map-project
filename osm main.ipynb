# %% [markdown]
# DATA WRANGLING: OPEN STREET MAP PROJECT
#
# OSM File = Hyderabad
#
# Hyderabad is the capital of the southern Indian state of Telangana and the de jure capital of Andhra Pradesh.  I've chosen Hyderabad  because, it's one most of the most commercial and developed cities in India.
#
# Reference link for Hyderabad.osm : https://mapzen.com/data/metro-extracts/metro/hyderabad_india/

# %% [markdown]
# Questions Explored :
#
# •Firstly, I’ve identified some street types from the imported data by matching the last name of street name with regular expression function, I’ve found that many of the last names of the street name were entered wrongly or by using shortcuts (i.e. Street as St or St.etc..) and some street names ended with numerical numbers representing the serial number of respective street name and some ended with white spaces.
# •Secondly, since Hyderabad is a district I want to differentiate Hyderabad city from Hyderabad district. This was done using the Postal Codes. Postal Codes ranging between 500010 and 500070 are considered to be in the city and the remaining are outside the city.

# %%
import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = "hyderabad_india.osm"  # Replace this with your osm file
SAMPLE_FILE = "sample.osm"

k = 10 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %% [markdown]
# STREET NAMES

# %% [markdown]
# 1. Identifying the abbreivated street names

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

osm_file = r'D:\Udacity\hyderabad_india.osm'
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
street_types=defaultdict(set)

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons" , "Nagar" , "Road" , "Tank" , "Lake" , "Valley" , "Enclave" ,
            "Apartment" , "Colony" , "Sector" , "Park" , "Nivas" , "Mall" , "Centre" , "Plaza"]

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")
street_types = defaultdict(set)
for event, elem in ET.iterparse(osm_file, events=("start",)):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if is_street_name(tag): 
                audit_street_type(street_types, tag.attrib['v'])

# %%
for i in street_types:
    print i
# Out:
# Hydera
# Gachibowlo
# Hills
# office
# NAGAR,AMBERPET
# vanasthallipuram
# Rd
# Cyberabad
# EFLU
# 4
# Paradise
# 15
# L.B.Nagar
# Gachibowli
# Bd
# Bowenpally,
# 20
# hills
# 22
# Rangareddy
# Singal
# Suchitra'X'Roads
# Hills,
# RD
# Narsingi
# amberpet
# shapurnagar
# Nagar,Gachibowli
# Estate
# circle
# maisammaguda
# green)
# Building
# 11
# junction
# Safilguda
# enclave
# L
# Phase
# 12
# Begumpet,
# Kismatpur
# nagar,borabanda
# 2
# BHEL
# uppuguda
# x;road
# Jeedimetla
# 14
# school
# Gadda,
# NALLAKUNTA,AMBERPET
# NAGAR
# Galli
# Dargah
# Kondapur
# Gowrinathapuram
# Attapur
# Marg
# godowns,vanasthalipuram.
# Area
# Hospital
# nagar
# s.j.b.hills
# street
# Abids
# Vanasthalipuram,
# Erragadda
# Hyderabad)
# 86
# Hyderabad,
# Dilsukhnagar
# Kothapet
# Miyapur
# Junction
# dammaiguda
# pet
# Balkampet
# No-92
# Gachibowl
# Prasanthinagar
# rd
# 3
# Mehdipatnam
# Balanagar,
# abids
# Padmanabhanagar,
# Sainikpuri
# miyapur
# Dammaiguda
# Rajendranagar
# Greens
# Hafeezpet
# Alkapuri
# Church
# 34
# met
# Konapur
# post
# QUARTERS
# Venkatapuram
# substation
# Hyderabad
# x-roads
# nagar,amberpet
# 36
# Mehedipatnam
# Roads
# pochampally
# Campus
# road
# 72
# Gadda
# S.R.Nagar
# Malkajgiri,
# colony
# Bazar
# kismatpur
# Bagh
# Meadows
# Kothaguda
# somajiguda
# dulapalle
# 5
# Ameerpet
# Begumpet
# Barkatpura
# Tarnaka,
# Hydernagar
# Gayatripuram
# Domalguda
# 10-D
# Kanajiguda
# lane
# chinthalkunta
# Madhapur
# Nacharam
# Flyover
# No.7
# No.3
# 8
# margh
# Amderpet
# Telangana
# market.
# 13
# Bazaar
# Temple)K.P.H.B.Colony
# Panjagutta
# Office
# Guda,
# laxminagar
# Road,AMBERPET
# Nizampet
# Madhapur,
# ROADS
# Gandipet
# Block,
# Mehedipatmam
# jntu
# raod
# Asmangadh
# Somajiguda
# City
# Peerzadiguda
# Layout
# Jubleehills
# Balkumpet
# Subashnagar
# R.C.Puram
# Colony,
# VenkateswaraNagar
# Madinaguda
# Circle
# Ramnagar.
# alwal
# Kukatpally
# Stop
# jubleehills
# CAMPUS
# 1
# AMBERPET
# Highway
# 4)
# 9
# Khajaguda
# bagh
# Uppuguda
# Secunderabad,
# 10
# A
# COLONY,AMBERPET
# nilayam
# Malkajgiri
# Madhinaguda
# Greenlands
# Fields
# Route
# gangaram
# Vanasthalipuram
# ameerpet
# NH7
# Residency
# 70
# phase
# Brahmanvadi
# Gardens
# Bridge
# kapra
# Vidyanagar.
# Vikrampuri
# lines
# Dwarakanagar
# Village
# Guda
# Gudimalkapur
# V.V.Nagar

# %% [markdown]
# Auditing Street names
#
# To deal with correcting street names, I opted to use regular expressions, correcting them to their respective mappings in the update_street_name  function

# %%
from collections import defaultdict
import re
import pprint
import xml.etree.cElementTree as ET

mapping = { "St": "Street",
            "udyog":"Udyog",
            "chaulk":"Chowk",
            "St.": "Street",
            "Ave":"Avenue",
            "chowk":"Chowk",
            "EFLU" :"",
            "Rd":"Road",
            "cross":"Cross",
            "Rd.":"Road",
            "nagar":"Nagar",
            "road":"Road",
            "raod":"Road",
            "apartment":"Apartment",
            "no.":"",
            "ROADS" : "Roads",
            "colony" : "Colony",
            "NH7" :"Highway"
           
        
            }
keys= mapping.keys() 

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
PROBLEMCHARS = re.compile(r'[=\+/&-<>;\'"\?%#$@\,\. \t\r\n]') 
LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+') 

def update_street_name(name, mapping):

        m = street_type_re.search(name)
        if m:
            street_type=m.group()
    
            if street_type in keys:
                value=mapping[street_type]
                y=name.find(street_type)
                z=name[:y]+value
                return z

            else:
                try: 
            
                    type(int(street_type))
                    position=name.find(street_type)
                    remove_numbers=name[:position]
                    return remove_numbers
          
                except ValueError:
                    x = name.replace(", "," ").replace(" ,"," ").replace(" No.","").replace(" no.","").replace(",","")
                    return x

# %%
for event, elem in ET.iterparse(osm_file, events=("start",)):
    if elem.tag == "node" or elem.tag == "way": 
        for tag in elem.iter("tag"):
            if is_street_name(tag):
                print "Before:",tag.attrib['v']
                print "After:",update_street_name(tag.attrib['v'], mapping)
# Out:
# Before: vijaynagar colony road
# After: vijaynagar colony Road
# Before: Sanjeeva Reddy Nagar Colony Main Road
# After: Sanjeeva Reddy Nagar Colony Main Road
# Before: Sarojini Devi Road
# After: Sarojini Devi Road
# Before: Adikmet Road, Vidyanagar.
# After: Adikmet Road Vidyanagar.
# Before: Difence colony
# After: Difence Colony
# Before: Vikrampuri
# After: Vikrampuri
# Before: RTC Colony
# After: RTC Colony
# Before: Shivam Road
# After: Shivam Road
# Before: Krishna Reddy Nagar
# After: Krishna Reddy Nagar
# Before: Kondapur X Road
# After: Kondapur X Road
# Before: Kothaguda
# After: Kothaguda
# Before: Lal Bazar
# After: Lal Bazar
# Before: Lal Bazar
# After: Lal Bazar
# Before: Lal Bazar
# After: Lal Bazar
# Before: Lal Bazar
# After: Lal Bazar
# Before: Sainikpuri
# After: Sainikpuri
# Before: Kanajiguda
# After: Kanajiguda
# Before: Kanajiguda
# After: Kanajiguda
# Before: Kanajiguda
# After: Kanajiguda
# Before: kamalapuri colony, srinagar colony
# After: kamalapuri Colony
# Before: Sardar Patel Road
# After: Sardar Patel Road
# Before: Malkajgiri Main Road
# After: Malkajgiri Main Road
# Before: Malkajgiri Main Road
# After: Malkajgiri Main Road
# Before: Sai Nagar Malkajgiri
# After: Sai Nagar Malkajgiri
# Before: Near Malkajgiri Bus Stop
# After: Near Malkajgiri Bus Stop
# Before: Vani Nagar
# After: Vani Nagar
# Before: Malkajgiri
# After: Malkajgiri
# Before: Vani Nagar
# After: Vani Nagar
# Before: Malkajgiri
# After: Malkajgiri
# Before: Malkajgiri
# After: Malkajgiri
# Before: Sai Nagar, Malkajgiri
# After: Sai Nagar Malkajgiri
# Before: RK Nagar
# After: RK Nagar
# Before: Kamalagiri Plaza, R.K. Nagar, Safilguda
# After: Kamalagiri Plaza R.K. Nagar Safilguda
# Before: Gautham Nagar
# After: Gautham Nagar
# Before: Gautham Nagar
# After: Gautham Nagar
# Before: Gautham Nagar
# After: Gautham Nagar
# Before: Gautham Nagar
# After: Gautham Nagar
# Before: Gautham Nagar
# After: Gautham Nagar
# Before: Gautham Nagar
# After: Gautham Nagar
# Before: Street No:9, Goutham Nagar
# After: Street No:9 Goutham Nagar
# Before: Malkajgiri
# After: Malkajgiri
# Before: VenkateswaraNagar
# After: VenkateswaraNagar
# Before: New Vidya Nagar Colony
# After: New Vidya Nagar Colony
# Before: Lalitha Nagar Road
# After: Lalitha Nagar Road
# Before: Madhapur
# After: Madhapur
# Before: Inner Ring Road
# After: Inner Ring Road
# Before: Liberty Road
# After: Liberty Road
# Before: Liberty Road
# After: Liberty Road
# Before: Nehru Outer Ring Road
# After: Nehru Outer Ring Road
# Before: IT Park Area
# After: IT Park Area
# Before: Road No 14, Banjara Hills
# After: Road No 14 Banjara Hills
# Before: HITEC City Main Road
# After: HITEC City Main Road
# Before: Rd No 2, Banjara Hills
# After: Rd No 2 Banjara Hills
# Before: Road No. 2, Banjara Hills
# After: Road 2 Banjara Hills
# Before: V Phase, KPHB Colony
# After: V Phase KPHB Colony
# Before: 3rd Phase,Near Bus Stop (Temple)K.P.H.B.Colony
# After: 3rd PhaseNear Bus Stop (Temple)K.P.H.B.Colony
# Before: opp.fruit market.
# After: opp.fruit market.
# Before: Hasmat pet
# After: Hasmat pet
# Before: sanath nagar
# After: sanath Nagar
# Before: 9
# After:
# Before: Sivarampally, Rajendranagar
# After: Sivarampally Rajendranagar
# Before: Chikoti Gardens
# After: Chikoti Gardens
# Before: 8-5-336,Vittal enclave
# After: 8-5-336Vittal enclave
# Before: nampally to mallapally road
# After: nampally to mallapally Road
# Before: Pragathi Nagar Road
# After: Pragathi Nagar Road
# Before: Yousufguda Main Road
# After: Yousufguda Main Road
# Before: Barkatpura
# After: Barkatpura
# Before: Green Fields
# After: Green Fields
# Before: Abids
# After: Abids
# Before: abids
# After: None
# Before: arunodaya colony
# After: arunodaya Colony
# Before: Masjid Banda Road
# After: Masjid Banda Road
# Before: First Lancer Road
# After: First Lancer Road
# Before: Sbiicm road
# After: Sbiicm Road
# Before: Red rose restaurant lane
# After: Red rose restaurant lane
# Before: banjara hills
# After: banjara hills
# Before: jubleehills
# After: jubleehills
# Before: Vengal Rao Nagar Main Road
# After: Vengal Rao Nagar Main Road
# Before: Nizampet Road
# After: Nizampet Road
# Before: Madhinaguda
# After: Madhinaguda
# Before: Prajay City
# After: Prajay City
# Before: Nagole main Road
# After: Nagole main Road
# Before: L. B. Nagar Junction
# After: L. B. Nagar Junction
# Before: back street
# After: back street
# Before: Madhapur Main Road
# After: Madhapur Main Road
# Before: Sri Rama Colony
# After: Sri Rama Colony
# Before: Foot over Bridge
# After: Foot over Bridge
# Before: EFLU
# After:
# Before: EFLU
# After:
# Before: Sreebagh Colony, Madhapur
# After: Sreebagh Colony Madhapur
# Before: Nagole-Bandlaguda Road
# After: Nagole-Bandlaguda Road
# Before: L.B.Nagar
# After: L.B.Nagar
# Before: Gujarati Galli
# After: Gujarati Galli
# Before: Nagarjuna Circle Road
# After: Nagarjuna Circle Road
# Before: Main Road, Miyapur
# After: Main Road Miyapur
# Before: Beside Pranam Hospital
# After: Beside Pranam Hospital
# Before: Madinaguda
# After: Madinaguda
# Before: Madinaguda
# After: Madinaguda
# Before: Madhapur
# After: Madhapur
# Before: Jubleehills
# After: Jubleehills
# Before: Madhapur Main Road
# After: Madhapur Main Road
# Before: Yapral-Ammuguda road
# After: Yapral-Ammuguda Road
# Before: Yapral-Ammuguda road
# After: Yapral-Ammuguda Road
# Before: Arul Colony, E C I L
# After: Arul Colony E C I L
# Before: Arul Colony
# After: Arul Colony
# Before: Gouthami Enclave
# After: Gouthami Enclave
# Before: Musheerabad Main Road
# After: Musheerabad Main Road
# Before: miyapur
# After: miyapur
# Before: miyapur
# After: miyapur
# Before: miyapur x-roads
# After: miyapur x-roads
# Before: Fever Hospital Road
# After: Fever Hospital Road
# Before: Vivekananda Nagar Road
# After: Vivekananda Nagar Road
# Before: towards alwal
# After: towards alwal
# Before: Jeedimetla
# After: Jeedimetla
# Before: Qutubullapur Main Road
# After: Qutubullapur Main Road
# Before: Quthubullapur Main Road
# After: Quthubullapur Main Road
# Before: Quthubullapur Main Road
# After: Quthubullapur Main Road
# Before: Vennala Gadda
# After: Vennala Gadda
# Before: Vennala Gadda,
# After: Vennala Gadda
# Before: Vennala Gadda,
# After: Vennala Gadda
# Before: Masjid Banda Road, Kondapur
# After: Masjid Banda Road Kondapur
# Before: Gudimalkapur, Mehedipatnam
# After: Gudimalkapur Mehedipatnam
# Before: Opp to Sai baba temple, Gudimalkapur crossroads, Mehedipatmam
# After: Opp to Sai baba temple Gudimalkapur crossroads Mehedipatmam
# Before: Groundfloor, Priya Colony, Gudimalkapur, Mehdipatnam
# After: Groundfloor Priya Colony Gudimalkapur Mehdipatnam
# Before: First Floor, Opp Sai Baba Temple, GudiMalkapur Rd, Gudi Malkapur, Mehedipatnam
# After: First Floor Opp Sai Baba Temple GudiMalkapur Rd Gudi Malkapur Mehedipatnam
# Before: Gudimalkapur Rd, Mehedipatnam
# After: Gudimalkapur Rd Mehedipatnam
# Before: Karwan Rd, Gudimalkapur, Mehedipatnam
# After: Karwan Rd Gudimalkapur Mehedipatnam
# Before: Karwan Rd, Gudimalkapur, Mehedipatnam
# After: Karwan Rd Gudimalkapur Mehedipatnam
# Before: Gudimalkapur Rd, Mehedipatnam
# After: Gudimalkapur Rd Mehedipatnam
# Before: Sai Baba Temple, Gudimalkapur, Mehedipatnam
# After: Sai Baba Temple Gudimalkapur Mehedipatnam
# Before: Inside Shivalayam temple, Gudimalkapur, Mehedipatnam
# After: Inside Shivalayam temple Gudimalkapur Mehedipatnam
# Before: Priya Colony, Gudimalkapur, Mehedipatnam
# After: Priya Colony Gudimalkapur Mehedipatnam
# Before: Priya Colony, Gudimalkapur, Mehedipatnam
# After: Priya Colony Gudimalkapur Mehedipatnam
# Before: kphb colony
# After: kphb Colony
# Before: Rajiv nagar X road
# After: Rajiv nagar X Road
# Before: Necklace Road
# After: Necklace Road
# Before: Meher Garden Rd, P & T Colony
# After: Meher Garden Rd P & T Colony
# Before: Priya Colony, Gudimalkapur, Mehedipatnam
# After: Priya Colony Gudimalkapur Mehedipatnam
# Before: Image Hosiptil Lane
# After: Image Hosiptil Lane
# Before: Indra Nagar, Gachibowli
# After: Indra Nagar Gachibowli
# Before: Old Bombay Road
# After: Old Bombay Road
# Before: Image Garden Road
# After: Image Garden Road
# Before: Erragadda
# After: Erragadda
# Before: Old Bombay Road
# After: Old Bombay Road
# Before: Raheja IT Park Road
# After: Raheja IT Park Road
# Before: Airport Flyover
# After: Airport Flyover
# Before: Yellareddyguda Road
# After: Yellareddyguda Road
# Before: BALAJI NAGAR
# After: BALAJI NAGAR
# Before: Yousufguda Main Road
# After: Yousufguda Main Road
# Before: Yousufguda Main Road
# After: Yousufguda Main Road
# Before: Yousufguda Main Road
# After: Yousufguda Main Road
# Before: Yousufguda Main Road
# After: Yousufguda Main Road
# Before: Yousufguda Main Road
# After: Yousufguda Main Road
# Before: Yousufguda Main Road
# After: Yousufguda Main Road
# Before: Yousufguda Main Road
# After: Yousufguda Main Road
# Before: Yousufguda Main Road
# After: Yousufguda Main Road
# Before: Yousufguda Main Road
# After: Yousufguda Main Road
# Before: Yousufguda Main Road
# After: Yousufguda Main Road
# Before: Yousufguda Main Road
# After: Yousufguda Main Road
# Before: S.R.Nagar
# After: S.R.Nagar
# Before: Hitec City - Kondapur Main Road
# After: Hitec City - Kondapur Main Road
# Before: JNTU Road
# After: JNTU Road
# Before: Opp Parda Gate King Koti Road
# After: Opp Parda Gate King Koti Road
# Before: Prof. C.R.Rao Road
# After: Prof. C.R.Rao Road
# Before: CIS road
# After: CIS Road
# Before: Indra Nagar Colony, Gachibowlo
# After: Indra Nagar Colony Gachibowlo
# Before: gajuularamaram road
# After: gajuularamaram Road
# Before: gajuularamaram road
# After: gajuularamaram Road
# Before: ushoday colony
# After: ushoday Colony
# Before: hal colony
# After: hal Colony
# Before: Jeedimetla Main Road
# After: Jeedimetla Main Road
# Before: substation
# After: substation
# Before: Madhuranagar Main Road
# After: Madhuranagar Main Road
# Before: Madhuranagar Main Road
# After: Madhuranagar Main Road
# Before: Madhuranagar Main Road
# After: Madhuranagar Main Road
# Before: Ameerpet Road
# After: Ameerpet Road
# Before: Shanthi Nagar Colony
# After: Shanthi Nagar Colony
# Before: adarsh Nagar
# After: adarsh Nagar
# Before: Adarsh Nagar
# After: Adarsh Nagar
# Before: Vinayak Nagar, Malkajgiri,
# After: Vinayak Nagar Malkajgiri
# Before: raimath nagar
# After: raimath Nagar
# Before: Zoo Park Main Road
# After: Zoo Park Main Road
# Before: habsiguda Main Road
# After: habsiguda Main Road
# Before: moosarambagh road
# After: moosarambagh Road
# Before: raimathnagar,yusufguda,near  government high school
# After: raimathnagaryusufgudanear  government high school
# Before: abdullapur met
# After: abdullapur met
# Before: Rajivgandhinagar, Prasanthinagar
# After: Rajivgandhinagar Prasanthinagar
# Before: ISB Road
# After: ISB Road
# Before: hafeezpet raod
# After: hafeezpet Road
# Before: Nacharam
# After: Nacharam
# Before: Habsiguda 'X' Roads
# After: Habsiguda 'X' Roads
# Before: Street no.1, Veerareddy colony, Karthikeya Nagar
# After: Street1 Veerareddy colony Karthikeya Nagar
# Before: road number 1
# After: road number
# Before: road number 1
# After: road number
# Before: Rajiv Nagar Colony, Venkatapuram
# After: Rajiv Nagar Colony Venkatapuram
# Before: plot no 9, sri ram nagar, kapra
# After: plot no 9 sri ram nagar kapra
# Before: Saheb Nagar, Vanasthalipuram
# After: Saheb Nagar Vanasthalipuram
# Before: Road No-92
# After: Road No-92
# Before: Road No 3
# After: Road No
# Before: Nizampet Road
# After: Nizampet Road
# Before: Cyber Hills, Guttala Begumpet, Madhapur
# After: Cyber Hills Guttala Begumpet Madhapur
# Before: Near Mithra Showroom, Himayath Nagar
# After: Near Mithra Showroom Himayath Nagar
# Before: shapurnagar
# After: shapurnagar
# Before: Raj Bhavan Road
# After: Raj Bhavan Road
# Before: Raj Bhavan Road
# After: Raj Bhavan Road
# Before: Raj Bhavan Road
# After: Raj Bhavan Road
# Before: Raj Bhavan Road
# After: Raj Bhavan Road
# Before: Raj Bhavan Road
# After: Raj Bhavan Road
# Before: Raj Bhavan Road
# After: Raj Bhavan Road
# Before: Raj Bhavan Road
# After: Raj Bhavan Road
# Before: Raj Bhavan Road
# After: Raj Bhavan Road
# Before: Raj Bhavan Road
# After: Raj Bhavan Road
# Before: HCU Main Road (University of Hyderabad)
# After: HCU Main Road (University of Hyderabad)
# Before: Habsiguda Main Road
# After: Habsiguda Main Road
# Before: HCU main road
# After: HCU main Road
# Before: HCU main road
# After: HCU main Road
# Before: Greenlands
# After: Greenlands
# Before: rajiv gandhi nagar,borabanda
# After: rajiv gandhi nagarborabanda
# Before: MANAGE Administrative Building Road
# After: MANAGE Administrative Building Road
# Before: RAJENDRA NAGAR
# After: RAJENDRA NAGAR
# Before: Balkampet
# After: Balkampet
# Before: Erragadda
# After: Erragadda
# Before: Balkumpet
# After: Balkumpet
# Before: Madhapur
# After: Madhapur
# Before: Hitec City - Kondapur Main Road
# After: Hitec City - Kondapur Main Road
# Before: Hitec City - Kondapur Main Road
# After: Hitec City - Kondapur Main Road
# Before: Whitefields Road
# After: Whitefields Road
# Before: Himayath Nagar Main Road
# After: Himayath Nagar Main Road
# Before: bk guda rd
# After: bk guda rd
# Before: bk guda rd
# After: bk guda rd
# Before: bk guda rd
# After: bk guda rd
# Before: bk guda rd
# After: bk guda rd
# Before: Western plaza street, OU colony
# After: Western plaza street, OU Colony
# Before: Gayatripuram
# After: Gayatripuram
# Before: Ameerpet
# After: Ameerpet
# Before: Sarojini Devi Road
# After: Sarojini Devi Road
# Before: Gopanapally Village
# After: Gopanapally Village
# Before: old mumbai road
# After: old mumbai Road
# Before: abids
# After: abids
# Before: Alkapuri
# After: Alkapuri
# Before: Nagarjuna Nagar
# After: Nagarjuna Nagar
# Before: panchayathi office
# After: panchayathi office
# Before: Road Number 13, Jubilee Hills
# After: Road Number 13 Jubilee Hills
# Before: narayana Jr college lane,Panama godowns,vanasthalipuram.
# After: narayana Jr college lanePanama godownsvanasthalipuram.
# Before: Subash Road
# After: Subash Road
# Before: Doolapally Road
# After: Doolapally Road
# Before: pochampally
# After: pochampally
# Before: dulapalle
# After: dulapalle
# Before: maisammaguda
# After: maisammaguda
# Before: Balanagar Cross Road
# After: Balanagar Cross Road
# Before: Adikmet, Road No.3
# After: Adikmet Road3
# Before: Ramnagar road, Ramnagar.
# After: Ramnagar road Ramnagar.
# Before: Ramnagar road, Ramnagar.
# After: Ramnagar road Ramnagar.
# Before: Golconda Road
# After: Golconda Road
# Before: (Municipal No. 15-25-531) Road No-1,  Phase No-1, Kukatpally Housing Board Colony,
# After: (Municipal 15-25-531) Road No-1  Phase No-1 Kukatpally Housing Board Colony
# Before: Green Hills Colony, Kothapet
# After: Green Hills Colony Kothapet
# Before: Rikab Gung RD
# After: Rikab Gung RD
# Before: Brundavan Colony, Narsingi
# After: Brundavan Colony Narsingi
# Before: surya hills
# After: surya hills
# Before: People's Hospital Lane, Kukatpally
# After: People's Hospital Lane Kukatpally
# Before: chowk road
# After: chowk Road
# Before: Ameerpet Road - Panjagutta Main Road
# After: Ameerpet Road - Panjagutta Main Road
# Before: Raja Reddy Marg
# After: Raja Reddy Marg
# Before: Ameerpet Road - Panjagutta Main Road
# After: Ameerpet Road - Panjagutta Main Road
# Before: big bazar lane, ameerpet
# After: big bazar lane ameerpet
# Before: songwriters colony
# After: songwriters Colony
# Before: Ameerpet Road - Panjagutta Main Road
# After: Ameerpet Road - Panjagutta Main Road
# Before: ameerpet circle
# After: ameerpet circle
# Before: panjagutta colony
# After: panjagutta Colony
# Before: Ameerpet Road - Panjagutta Main Road
# After: Ameerpet Road - Panjagutta Main Road
# Before: Bone Factory Road
# After: Bone Factory Road
# Before: Golnaka Road
# After: Golnaka Road
# Before: Adarsh Nagar
# After: Adarsh Nagar
# Before: vijaynagar colony circle
# After: vijaynagar colony circle
# Before: Somajiguda Road - Panjagutta Main Road
# After: Somajiguda Road - Panjagutta Main Road
# Before: street number 1
# After: street number
# Before: Maula Ali Road
# After: Maula Ali Road
# Before: Nizampet
# After: Nizampet
# Before: Soldier Bd, Somajiguda
# After: Soldier Bd Somajiguda
# Before: Jai jawan colony
# After: Jai jawan Colony
# Before: baddam balreddy nagar
# After: baddam balreddy Nagar
# Before: BADDAM BALREDDY NAGAR
# After: BADDAM BALREDDY NAGAR
# Before: BADDAM BALREDDY NAGAR
# After: BADDAM BALREDDY NAGAR
# Before: BADDAM BALREDDY NAGAR
# After: BADDAM BALREDDY NAGAR
# Before: TOLICHOWKI X ROADS
# After: TOLICHOWKI X Roads
# Before: Gachibowli - Miyapur Highway
# After: Gachibowli - Miyapur Highway
# Before: Ameerpet Road - Panjagutta Main Road
# After: Ameerpet Road - Panjagutta Main Road
# Before: 6 number road
# After: 6 number Road
# Before: Paramount Hills
# After: Paramount Hills
# Before: Gandhinagar road
# After: Gandhinagar Road
# Before: Old Bombay Road
# After: Old Bombay Road
# Before: Hi Tech City Main Road
# After: Hi Tech City Main Road
# Before: Pupplaguda - Shaikpet Rd
# After: Pupplaguda - Shaikpet Road
# Before: 4
# After:
# Before: Khajaguda
# After: Khajaguda
# Before: Hussain Shah Wali Dargah
# After: Hussain Shah Wali Dargah
# Before: Hussain Shah Wali Dargah
# After: Hussain Shah Wali Dargah
# Before: Dargah Hussain Shah Wali road
# After: Dargah Hussain Shah Wali Road
# Before: vijaynagar colony road
# After: vijaynagar colony Road
# Before: Anand Nagar Entrance Road
# After: Anand Nagar Entrance Road
# Before: Hydernagar
# After: Hydernagar
# Before: Mallapur Road
# After: Mallapur Road
# Before: Mallapur Road
# After: Mallapur Road
# Before: Mallapur Road
# After: Mallapur Road
# Before: Mallapur Road
# After: Mallapur Road
# Before: Mallapur Road
# After: Mallapur Road
# Before: Mallapur Road
# After: Mallapur Road
# Before: Narsinha Colony,Mallapur Rd
# After: Narsinha Colony,Mallapur Road
# Before: Narsinha Colony,Mallapur Rd
# After: Narsinha Colony,Mallapur Road
# Before: Narsinha Colony,Mallapur Rd
# After: Narsinha Colony,Mallapur Road
# Before: Narsinha Colony,Mallapur Rd
# After: Narsinha Colony,Mallapur Road
# Before: Narsinha Colony,Mallapur Rd
# After: Narsinha Colony,Mallapur Road
# Before: Narsinha Colony,Mallapur Rd
# After: Narsinha Colony,Mallapur Road
# Before: Narsinha Colony,Mallapur Rd
# After: Narsinha Colony,Mallapur Road
# Before: Sainikpuri-ECIL Main Road
# After: Sainikpuri-ECIL Main Road
# Before: Narsinha Colony,Mallapur Rd
# After: Narsinha Colony,Mallapur Road
# Before: Narsinha Colony,Mallapur Rd
# After: Narsinha Colony,Mallapur Road
# Before: Sainikpuri-ECIL Main Road
# After: Sainikpuri-ECIL Main Road
# Before: BN Reddy Nagar
# After: BN Reddy Nagar
# Before: BN Reddy Nagar
# After: BN Reddy Nagar
# Before: BN Reddy Nagar
# After: BN Reddy Nagar
# Before: BN Reddy Nagar
# After: BN Reddy Nagar
# Before: BN Reddy Nagar
# After: BN Reddy Nagar
# Before: BN Reddy Nagar
# After: BN Reddy Nagar
# Before: BN Reddy Nagar
# After: BN Reddy Nagar
# Before: BN Reddy Nagar
# After: BN Reddy Nagar
# Before: BN Reddy Nagar
# After: BN Reddy Nagar
# Before: Cherlapalli Industrial Area
# After: Cherlapalli Industrial Area
# Before: Cherlapalli Industrial Area
# After: Cherlapalli Industrial Area
# Before: Cherlapalli Industrial Area
# After: Cherlapalli Industrial Area
# Before: White Orchids Homes, Hydernagar, Madhapur
# After: White Orchids Homes Hydernagar Madhapur
# Before: Vinayagar Mangalagiri Apartments, Road Number 10, Avenue 4, Banjara Hills
# After: Vinayagar Mangalagiri Apartments Road Number 10 Avenue 4 Banjara Hills
# Before: Jubilee Hills
# After: Jubilee Hills
# Before: Road No 13
# After: Road No
# Before: Jubilee Hills
# After: Jubilee Hills
# Before: Jubilee Hills
# After: Jubilee Hills
# Before: Jubilee Hills
# After: Jubilee Hills
# Before: Lake Valley Residential Society, Banjara Hills
# After: Lake Valley Residential Society Banjara Hills
# Before: Road No 12 Koushik Co-Operative Society, Banjara Hills
# After: Road No 12 Koushik Co-Operative Society Banjara Hills
# Before: Brindavan Colony, Madhapur
# After: Brindavan Colony Madhapur
# Before: Road No 12, Mla Colony, Banjara Hills
# After: Road No 12 Mla Colony Banjara Hills
# Before: Park Enclave, Road No 12, Banjara Hills
# After: Park Enclave Road No 12 Banjara Hills
# Before: , Jubilee Enclave-Hitech City
# After:  Jubilee Enclave-Hitech City
# Before: maskan, Civil supplies bhavan lane
# After: maskan Civil supplies bhavan lane
# Before: , Green Land Road, Panjagutta
# After:  Green Land Road Panjagutta
# Before: Kanthi shikara apartments, Panjagutta
# After: Kanthi shikara apartments Panjagutta
# Before: Venkata Ramana Colony, Banjara Hills
# After: Venkata Ramana Colony Banjara Hills
# Before: Kundanbagh, Begumpet,
# After: Kundanbagh Begumpet
# Before: Airport Road, Attapur
# After: Airport Road Attapur
# Before: Gowli Guda
# After: Gowli Guda
# Before: Khan Lateefkhan Estate
# After: Khan Lateefkhan Estate
# Before: 100 Feet Road Ayyappa Society, Madhapur
# After: 100 Feet Road Ayyappa Society Madhapur
# Before: Guttala Begumpet, Madhapur
# After: Guttala Begumpet Madhapur
# Before: 100 Feet Road Ayyappa Society, Madhapur
# After: 100 Feet Road Ayyappa Society Madhapur
# Before: Hi-Tech City Road, Madhapur
# After: Hi-Tech City Road Madhapur
# Before: Mohan Elite, 4th Floor, Beside Smiline Dental Hospital, Hitech City
# After: Mohan Elite 4th Floor Beside Smiline Dental Hospital Hitech City
# Before: Ameerpet Road - Panjagutta Main Road
# After: Ameerpet Road - Panjagutta Main Road
# Before: shivalayam road
# After: shivalayam Road
# Before: Gachibowli
# After: Gachibowli
# Before: PALM Road - Balanagar Road
# After: PALM Road - Balanagar Road
# Before: Kishan Guda, Shamshabad, Rangareddy
# After: Kishan Guda Shamshabad Rangareddy
# Before: B-73 apie, IDA, Balanagar, Hyderabad,
# After: B-73 apie IDA Balanagar Hyderabad
# Before: Jayabheri Enclave, Kothaguda, Gachibowli
# After: Jayabheri Enclave Kothaguda Gachibowli
# Before: IInd floor, 21, Ceon Road, Jayabheri Pine Valley, Gachibowl
# After: IInd floor 21 Ceon Road Jayabheri Pine Valley Gachibowl
# Before: Raj Bhavan Road, Somajiguda
# After: Raj Bhavan Road Somajiguda
# Before: Durga Enclave, Road No 12, Banjara Hills
# After: Durga Enclave Road No 12 Banjara Hills
# Before: New Nagole Road, Samathapuri, Samathapuri Colony, Hyderabad,
# After: New Nagole Road Samathapuri Samathapuri Colony Hyderabad
# Before: Plot No B-69, Apie, Balanagar, Ashok Nagar, Balanagar,
# After: Plot No B-69 Apie Balanagar Ashok Nagar Balanagar
# Before: Naik Estate, Begumpet
# After: Naik Estate Begumpet
# Before: 1st Floor,Legend Apartments, Motilal Nehru Marg, Begumpet
# After: 1st FloorLegend Apartments Motilal Nehru Marg Begumpet
# Before: Road No11, Banjara Hills
# After: Road No11 Banjara Hills
# Before: Sikh Road, Old Bowenpally;nr Market Yard, Sikh Road, Radha Swamy Colony, Bowenpally,
# After: Sikh Road Old Bowenpally;nr Market Yard Sikh Road Radha Swamy Colony Bowenpally
# Before: P.V.R. Hi-Tech School Building, Bansilalpet, Gandhinagar,, Secunderabad, Bansilalpet, Bhoiguda, hyderabad, Telangana
# After: P.V.R. Hi-Tech School Building Bansilalpet Gandhinagar Secunderabad Bansilalpet Bhoiguda hyderabad Telangana
# Before: Road No-11, Banjara Hills
# After: Road No-11 Banjara Hills
# Before: Drnayanthi Chamber, Adarsh Nagar, Adarsh Nagar, Hyderabad, Telangana
# After: Drnayanthi Chamber Adarsh Nagar Adarsh Nagar Hyderabad Telangana
# Before: 2, Sarojini Devi Rd, Regimental Bazaar, Shivaji Nagar, Ranga Reddy,, Secunderabad,
# After: 2 Sarojini Devi Rd Regimental Bazaar Shivaji Nagar Ranga Reddy Secunderabad
# Before: ,Valley View Apartments, Banjara Hills
# After: Valley View Apartments Banjara Hills
# Before: Naik Estate, Begumpet
# After: Naik Estate Begumpet
# Before: Srinivas Naik Estate, Street No 1, Begumpet
# After: Srinivas Naik Estate Street No 1 Begumpet
# Before: Mithilanagar Colony, Banjara Hills
# After: Mithilanagar Colony Banjara Hills
# Before: Kirtilal Jewellery Lane
# After: Kirtilal Jewellery Lane
# Before: Road No 45, Jubilee Hills
# After: Road No 45 Jubilee Hills
# Before: , Road No 11, Lake Valley Residential Society, Banjara Hills
# After:  Road No 11 Lake Valley Residential Society Banjara Hills
# Before: Road No 12, Mla Colony, Banjara Hills
# After: Road No 12 Mla Colony Banjara Hills
# Before: Kundanbagh, Begumpet
# After: Kundanbagh Begumpet
# Before: mallapur road
# After: mallapur Road
# Before: mallapur road
# After: mallapur Road
# Before: mallapur road
# After: mallapur Road
# Before: panama archi besides Building
# After: panama archi besides Building
# Before: Venkateshwara Nagar Colony
# After: Venkateshwara Nagar Colony
# Before: VANDANAPURI COLONY STREET NO. 3
# After: VANDANAPURI COLONY STREET NO.
# Before: L. B. Nagar Junction
# After: L. B. Nagar Junction
# Before: vijaynagar colony road
# After: vijaynagar colony Road
# Before: Jeedimetla Main Road
# After: Jeedimetla Main Road
# Before: Road No 14
# After: Road No
# Before: Masjid Banda Road
# After: Masjid Banda Road
# Before: Gouthami Enclave
# After: Gouthami Enclave
# Before: kishan bagh
# After: kishan bagh
# Before: tellapur road
# After: tellapur Road
# Before: Masjid Banda Road
# After: Masjid Banda Road
# Before: Jubilee Hills Road No 36
# After: Jubilee Hills Road No
# Before: Lb Nagar ,chinthalkunta
# After: Lb Nagar chinthalkunta
# Before: chinthalkunta,Lb Nagar
# After: chinthalkuntaLb Nagar
# Before: chinthalkunta,lb Nagar Hyderabad
# After: chinthalkuntalb Nagar Hyderabad
# Before: chinthalkunta Singal
# After: chinthalkunta Singal
# Before: chinthalkunta
# After: chinthalkunta
# Before: Oppsite. Hotel Sitara Grand, L.B. 'X', Road, Sai Sadan Complex, Vivekananda Colony, LB Nagar, Hydera
# After: Oppsite. Hotel Sitara Grand L.B. 'X' Road Sai Sadan Complex Vivekananda Colony LB Nagar Hydera
# Before: L. B. Nagar Junction
# After: L. B. Nagar Junction
# Before: street no 8
# After: street no
# Before: CIS road
# After: CIS Road
# Before: Road No 70
# After: Road No
# Before: Chinthalkunta old check post
# After: Chinthalkunta old check post
# Before: Street No. 10
# After: Street No.
# Before: Street No. 10
# After: Street No.
# Before: Financial District, Nanakram Guda
# After: Financial District Nanakram Guda
# Before: Ground Floor Shop Number 3 & 4, Food Court Wave Rock Building, Sy no 115(p) APIIC IT / ITES Special Economic Zone, Nanakramguda Village Serilingampally Mandal, Financial District, Nanakram Guda,
# After: Ground Floor Shop Number 3 & 4 Food Court Wave Rock Building Sy no 115(p) APIIC IT / ITES Special Economic Zone Nanakramguda Village Serilingampally Mandal Financial District Nanakram Guda
# Before: WaveRock SEZ, IT Number 2, Nanakramguda,, Gachibowli Rd, Financial District, Nanakram Guda,
# After: WaveRock SEZ IT Number 2 Nanakramguda Gachibowli Rd Financial District Nanakram Guda
# Before: SEZ Unit, South Tower Bar Building, TSA Business Park, Nanakram Guda, Financial District, Nanakram Guda
# After: SEZ Unit South Tower Bar Building TSA Business Park Nanakram Guda Financial District Nanakram Guda
# Before: 100 Feet Road, Silicon Valley, Madhapur
# After: 100 Feet Road Silicon Valley Madhapur
# Before: pannama Road
# After: pannama Road
# Before: L. B. Nagar Junction
# After: L. B. Nagar Junction
# Before: kaminpet hospital road
# After: kaminpet hospital Road
# Before: Pannama junction
# After: Pannama junction
# Before: Chinthalkunta - Lb Nagar
# After: Chinthalkunta - Lb Nagar
# Before: 71-72, Road No.36, Jubilee Hills Extension, near Jubilee Ridge Hotel, Kavuri Hills, Madhapur, Hydera
# After: 71-72 Road36 Jubilee Hills Extension near Jubilee Ridge Hotel Kavuri Hills Madhapur Hydera
# Before: Dammaiguda
# After: Dammaiguda
# Before: dammaiguda
# After: dammaiguda
# Before: dammaiguda
# After: dammaiguda
# Before: lane number 1
# After: lane number
# Before: Netaji Nagar
# After: Netaji Nagar
# Before: Wipro Circle
# After: Wipro Circle
# Before: Yousuf Baba Dargah Road
# After: Yousuf Baba Dargah Road
# Before: KPHB 6th Phase Road
# After: KPHB 6th Phase Road
# Before: Nampally to Mallepally Road
# After: Nampally to Mallepally Road
# Before: Dilsukhnagar
# After: Dilsukhnagar
# Before: navajeevan nagar
# After: navajeevan Nagar
# Before: Manikonda Village, Gatchibowli SEZ, Madhava Reddy Colony, Gachibowli
# After: Manikonda Village Gatchibowli SEZ Madhava Reddy Colony Gachibowli
# Before: Anjaiah Nagar,Gachibowli
# After: Anjaiah NagarGachibowli
# Before: Road No 3
# After: Road No
# Before: gajularamaram road
# After: gajularamaram Road
# Before: vanasthallipuram
# After: vanasthallipuram
# Before: Pipeline Road
# After: Pipeline Road
# Before: Dhoopet road
# After: Dhoopet Road
# Before: Dhoolpet Road
# After: Dhoolpet Road
# Before: Lowar Dhoolpet Road
# After: Lowar Dhoolpet Road
# Before: Begum Bazaar
# After: Begum Bazaar
# Before: Parwathi Nagar Road no 1, Peerzadiguda
# After: Parwathi Nagar Road no 1 Peerzadiguda
# Before: Santoshima Colony
# After: Santoshima Colony
# Before: Yousufguda Police Lines (Street #4)
# After: Yousufguda Police Lines (Street #4)
# Before: Yousufguda Police Lines (Street #4)
# After: Yousufguda Police Lines (Street #4)
# Before: Ragala Enclave Rd
# After: Ragala Enclave Road
# Before: Vittal Rao Nagar Madhapur,
# After: Vittal Rao Nagar Madhapur
# Before: sathyanarayana Puram Road
# After: sathyanarayana Puram Road
# Before: Police lines
# After: Police lines
# Before: police lines
# After: police lines
# Before: Vijayapuri Colony
# After: Vijayapuri Colony
# Before: Roas No. 4
# After: Roas No.
# Before: Inorbit Mall Road
# After: Inorbit Mall Road
# Before: Indira park road
# After: Indira park Road
# Before: Inorbit Mall Road
# After: Inorbit Mall Road
# Before: Gandipet
# After: Gandipet
# Before: Gandipet
# After: Gandipet
# Before: x;road
# After: x;road
# Before: road no 1, Banjara Hills,
# After: road no 1 Banjara Hills
# Before: Banjarahiils, Rd. No. 3
# After: Banjarahiils, Rd. No.
# Before: Kothapet Road
# After: Kothapet Road
# Before: Inner Ring Road
# After: Inner Ring Road
# Before: MJ Colony
# After: MJ Colony
# Before: HITEC City Main Road
# After: HITEC City Main Road
# Before: Pragati Nagar
# After: Pragati Nagar
# Before: Gachibowli
# After: Gachibowli
# Before: Abids
# After: Abids
# Before: Abids road
# After: Abids Road
# Before: Inner Ring Road
# After: Inner Ring Road
# Before: Amderpet
# After: Amderpet
# Before: Annapoorna Block,
# After: Annapoorna Block
# Before: Foreigners Regional Registration Office
# After: Foreigners Regional Registration Office
# Before: Sitaphalmandi Main Road
# After: Sitaphalmandi Main Road
# Before: Sitaphalmandi Main Road
# After: Sitaphalmandi Main Road
# Before: Sitaphalmandi Main Road
# After: Sitaphalmandi Main Road
# Before: Sitaphalmandi Main Road
# After: Sitaphalmandi Main Road
# Before: Sitaphalmandi Main Road
# After: Sitaphalmandi Main Road
# Before: Sitaphalmandi Main Road
# After: Sitaphalmandi Main Road
# Before: Osmania University Main Road
# After: Osmania University Main Road
# Before: Ravindra Nagar
# After: Ravindra Nagar
# Before: Inner Ring Road
# After: Inner Ring Road
# Before: Uppal Khalsa Village, Inner Ring Road
# After: Uppal Khalsa Village Inner Ring Road
# Before: Siddartha Nagar Road number 3
# After: Siddartha Nagar Road number
# Before: Sarojini Devi Road
# After: Sarojini Devi Road
# Before: santhi nagar
# After: santhi Nagar
# Before: Dwarakanagar
# After: Dwarakanagar
# Before: Suchitra Junction
# After: Suchitra Junction
# Before: Subashnagar
# After: Subashnagar
# Before: venkat reddy nagar street
# After: venkat reddy nagar street
# Before: BHEL
# After: BHEL
# Before: BHEL
# After: BHEL
# Before: V.V.Nagar
# After: V.V.Nagar
# Before: BHEL
# After: BHEL
# Before: BHEL
# After: BHEL
# Before: BHEL
# After: BHEL
# Before: BHEL
# After: BHEL
# Before: Miyapur
# After: Miyapur
# Before: Laxmi Nagar, Mehdipatnam
# After: Laxmi Nagar Mehdipatnam
# Before: Suchitra'X'Roads
# After: Suchitra'X'Roads
# Before: Nizamabad Road;old NH7
# After: Nizamabad Road;old Highway
# Before: Rajeev Nagar
# After: Rajeev Nagar
# Before: gangaram
# After: gangaram
# Before: gangaram
# After: gangaram
# Before: Engineers Enclave
# After: Engineers Enclave
# Before: Minister Road, kims Hospital
# After: Minister Road kims Hospital
# Before: Prenderghast Road
# After: Prenderghast Road
# Before: Prenderghast Road
# After: Prenderghast Road
# Before: Ushodaya Colony, Gudimalkapur
# After: Ushodaya Colony Gudimalkapur
# Before: acharya chanakya margh
# After: acharya chanakya margh
# Before: Mourya Ranga Prasad Avenue, Gachibowli
# After: Mourya Ranga Prasad Avenue Gachibowli
# Before: Inorbit Mall Road
# After: Inorbit Mall Road
# Before: Cyberabad
# After: Cyberabad
# Before: Inorbit Mall Road
# After: Inorbit Mall Road
# Before: Gaganmahal Road, Domalguda
# After: Gaganmahal Road Domalguda
# Before: Street No. 10, Domalguda
# After: Street 10 Domalguda
# Before: rci road
# After: rci Road
# Before: JNTU Campus
# After: JNTU Campus
# Before: Chaitanyapuri Colony
# After: Chaitanyapuri Colony
# Before: Domalguda, Gaganmahal Road No.7
# After: Domalguda Gaganmahal Road7
# Before: Prakashnagar Road
# After: Prakashnagar Road
# Before: jntu
# After: jntu
# Before: mallikarjuna nagar,amberpet
# After: mallikarjuna nagaramberpet
# Before: MALLIKARJUNA NAGAR,AMBERPET
# After: MALLIKARJUNA NAGARAMBERPET
# Before: DD COLONY,AMBERPET
# After: DD COLONYAMBERPET
# Before: DD COLONY ,AMBERPET
# After: DD COLONY AMBERPET
# Before: DD COLONY,AMBERPET
# After: DD COLONYAMBERPET
# Before: DD COLONY,AMBERPET
# After: DD COLONYAMBERPET
# Before: RAMAKRISHNA NAGAR,AMBERPET
# After: RAMAKRISHNA NAGARAMBERPET
# Before: AMBERPET
# After: AMBERPET
# Before: Nallakunta Road,AMBERPET
# After: Nallakunta RoadAMBERPET
# Before: Shivam Road,AMBERPET
# After: Shivam RoadAMBERPET
# Before: NEW NALLAKUNTA,AMBERPET
# After: NEW NALLAKUNTAAMBERPET
# Before: Shivam Road
# After: Shivam Road
# Before: 6th phase
# After: 6th phase
# Before: kamala nagar
# After: kamala Nagar
# Before: mallikarjuna nagar,amberpet
# After: mallikarjuna nagaramberpet
# Before: ramakrishna nagar ,amberpet
# After: ramakrishna nagar amberpet
# Before: RAMAKRISHNA NAGAR,AMBERPET
# After: RAMAKRISHNA NAGARAMBERPET
# Before: RAMAKRISHNA NAGAR,AMBERPET
# After: RAMAKRISHNA NAGARAMBERPET
# Before: RAMAKRISHNA NAGAR,AMBERPET
# After: RAMAKRISHNA NAGARAMBERPET
# Before: RAMAKRISHNA NAGAR,AMBERPET
# After: RAMAKRISHNA NAGARAMBERPET
# Before: CENTRAL EXCISE COLONY ,AMBERPET
# After: CENTRAL EXCISE COLONY AMBERPET
# Before: Shivam Road
# After: Shivam Road
# Before: Balaji Nagar
# After: Balaji Nagar
# Before: opp. substation
# After: opp. substation
# Before: s.j.b.hills
# After: s.j.b.hills
# Before: GRIET College Rd
# After: GRIET College Road
# Before: Shanthi Nagar Colony
# After: Shanthi Nagar Colony
# Before: vani nilayam
# After: vani nilayam
# Before: Vinayaka Nagar, Hafeezpet
# After: Vinayaka Nagar Hafeezpet
# Before: Balkampet, S R Nagar
# After: Balkampet S R Nagar
# Before: 60 Feet Rd Mega Hills, Madhapur
# After: 60 Feet Rd Mega Hills Madhapur
# Before: Indra Reddy Allwyn Colony
# After: Indra Reddy Allwyn Colony
# Before: kukatpally road
# After: kukatpally Road
# Before: 100 Feet Road, Silicon Valley, Madhapur
# After: 100 Feet Road Silicon Valley Madhapur
# Before: Sri Nagar Colony Main Road
# After: Sri Nagar Colony Main Road
# Before: KPHB 6th Phase Road
# After: KPHB 6th Phase Road
# Before: Moosarambagh Rd Malakpet Extension Dilsukhnagar
# After: Moosarambagh Rd Malakpet Extension Dilsukhnagar
# Before: Habsiguda Main Road
# After: Habsiguda Main Road
# Before: Road No 36
# After: Road No
# Before: Vidyanagar Railway Stn. Road
# After: Vidyanagar Railway Stn. Road
# Before: Zoo Park Main Road
# After: Zoo Park Main Road
# Before: Hyderabad Metro Line 2 (green)
# After: Hyderabad Metro Line 2 (green)
# Before: Hyderabad Metro Line 2 (green)
# After: Hyderabad Metro Line 2 (green)
# Before: Madhapur Main Road
# After: Madhapur Main Road
# Before: picket rd
# After: picket rd
# Before: Hitec City - Kondapur Main Road
# After: Hitec City - Kondapur Main Road
# Before: ISB Road
# After: ISB Road
# Before: K P H B Phase 3 Kukatpally
# After: K P H B Phase 3 Kukatpally
# Before: LB Nagar
# After: LB Nagar
# Before: Nizampet Road
# After: Nizampet Road
# Before: Dr A.S.Rao Nagar Road;Dr. A.S.Rao Nagar Road
# After: Dr A.S.Rao Nagar Road;Dr. A.S.Rao Nagar Road
# Before: 22
# After:
# Before: Pridhvi Residence
# After: None
# Before: Hi Rise Meadows
# After: Hi Rise Meadows
# Before: ushodaya colony phase 1
# After: ushodaya colony phase
# Before: rci road
# After: rci Road
# Before: lane number 3
# After: lane number
# Before: dammaiguda
# After: dammaiguda
# Before: Road No 3
# After: Road No
# Before: HUDA Sai Nagar Colony, Vanasthalipuram,
# After: HUDA Sai Nagar Colony Vanasthalipuram
# Before: Huda Sai Nagar Colony, Vanasthalipuram,
# After: Huda Sai Nagar Colony Vanasthalipuram
# Before: Dwarakamai Nagar, Vanasthalipuram
# After: Dwarakamai Nagar Vanasthalipuram
# Before: Dwarakamai Nagar, Vanasthalipuram
# After: Dwarakamai Nagar Vanasthalipuram
# Before: KPHB 9th Phase Road
# After: KPHB 9th Phase Road
# Before: Villa Greens
# After: Villa Greens
# Before: sapthagiri colony
# After: sapthagiri Colony
# Before: Lane 34
# After: Lane
# Before: Sports Complex Road
# After: Sports Complex Road
# Before: HCU main road (University of Hyderabad)
# After: HCU main road (University of Hyderabad)
# Before: HUDA Colony
# After: HUDA Colony
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: Road no 8
# After: Road no
# Before: Miyapur
# After: Miyapur
# Before: Miyapur
# After: Miyapur
# Before: road no 4
# After: road no
# Before: 1 st street
# After: 1 st street
# Before: Raj Bhavan Road, Somajiguda
# After: Raj Bhavan Road Somajiguda
# Before: civil supplies bhavan lane, somajiguda
# After: civil supplies bhavan lane somajiguda
# Before: Raj Bhavan Road, Somajiguda
# After: Raj Bhavan Road Somajiguda
# Before: Yousufguda Police Lines (Street #4)
# After: Yousufguda Police Lines (Street #4)
# Before: Janakpuri Colony
# After: Janakpuri Colony
# Before: Hi Tech City Main Road
# After: Hi Tech City Main Road
# Before: Bhavani Nagar
# After: Bhavani Nagar
# Before: Jeedimetla Main Road
# After: Jeedimetla Main Road
# Before: BP Raju Marg, Kondapur
# After: BP Raju Marg Kondapur
# Before: Road no 2, Jubilee Hills
# After: Road no 2 Jubilee Hills
# Before: road no 31, Jubilee Hills
# After: road no 31 Jubilee Hills
# Before: Sardar Patel Road
# After: Sardar Patel Road
# Before: Gopisetty Residency
# After: Gopisetty Residency
# Before: Raj Bhavan Road
# After: Raj Bhavan Road
# Before: Old Bombay Highway
# After: Old Bombay Highway
# Before: Gafoor Nagar
# After: Gafoor Nagar
# Before: Paradise
# After: Paradise
# Before: Madhuranagar Main Road
# After: Madhuranagar Main Road
# Before: Road Number 2
# After: Road Number
# Before: new shapurnagar
# After: new shapurnagar
# Before: sathyanarayana Puram Road
# After: sathyanarayana Puram Road
# Before: Ayodhya Enclave, 2nd Lane
# After: Ayodhya Enclave 2nd Lane
# Before: Karthikeyanagar Main Road
# After: Karthikeyanagar Main Road
# Before: Brahmanvadi
# After: Brahmanvadi
# Before: street no: 20
# After: street no:
# Before: Sarojini Devi Road
# After: Sarojini Devi Road
# Before: Sarojini Devi Road
# After: Sarojini Devi Road
# Before: Sardar Patel Rd
# After: Sardar Patel Road
# Before: Sardar Patel Rd
# After: Sardar Patel Road
# Before: Bapu Nagar Road
# After: Bapu Nagar Road
# Before: Raj Bhavan Road, Somajiguda
# After: Raj Bhavan Road Somajiguda
# Before: Raj Bhavan Road
# After: Raj Bhavan Road
# Before: laxminagar
# After: laxminagar
# Before: Soldier Bd, Somajiguda
# After: Soldier Bd Somajiguda
# Before: Soldier Bd
# After: Soldier Bd
# Before: Road No 15
# After: Road No
# Before: Road No 12
# After: Road No
# Before: Road No 11
# After: Road No
# Before: Road No 12
# After: Road No
# Before: Road No 15
# After: Road No
# Before: Road No 15
# After: Road No
# Before: Road No 15
# After: Road No
# Before: Road No 15
# After: Road No
# Before: Road No 15
# After: Road No
# Before: Road No 12
# After: Road No
# Before: Road No 11
# After: Road No
# Before: Road No 11
# After: Road No
# Before: Road No 15
# After: Road No
# Before: Road No 12
# After: Road No
# Before: Road No 15
# After: Road No
# Before: Road No 15
# After: Road No
# Before: Road No 12
# After: Road No
# Before: Boorugu Vihar, Begumpet
# After: Boorugu Vihar Begumpet
# Before: Road no 10
# After: Road no
# Before: Road Number 86
# After: Road Number
# Before: Asmangadh
# After: Asmangadh
# Before: D d colony Lane A
# After: D d colony Lane A
# Before: Street No : 3
# After: Street No :
# Before: Tilak Road
# After: Tilak Road
# Before: Road No 15
# After: Road No
# Before: Road No 72
# After: Road No
# Before: Road No 72
# After: Road No
# Before: Road No 15
# After: Road No
# Before: Road No 72
# After: Road No
# Before: Road No 72
# After: Road No
# Before: Road No 72
# After: Road No
# Before: Road No 72
# After: Road No
# Before: Road No 72
# After: Road No
# Before: Road No 72
# After: Road No
# Before: Road No 15
# After: Road No
# Before: Hitec City - Kondapur Main Road
# After: Hitec City - Kondapur Main Road
# Before: Saraswathi nagar colony
# After: Saraswathi nagar Colony
# Before: vijaynagar colony circle
# After: vijaynagar colony circle
# Before: Karolbagh B, Padmanabhanagar,
# After: Karolbagh B Padmanabhanagar
# Before: rajiv gandhi nagar,borabanda
# After: rajiv gandhi nagarborabanda
# Before: Priya Colony
# After: Priya Colony
# Before: Vijayapuri, Tarnaka,
# After: Vijayapuri Tarnaka
# Before: Kismatpur
# After: Kismatpur
# Before: Balamrai Road
# After: Balamrai Road
# Before: Street number 9
# After: Street number
# Before: Street number 9
# After: Street number
# Before: Parwathi Nagar Road No 1
# After: Parwathi Nagar Road No
# Before: Street number 9
# After: Street number
# Before: Parwathi Nagar Road No 1
# After: Parwathi Nagar Road No
# Before: Street number 9
# After: Street number
# Before: Street number 9
# After: Street number
# Before: Street number 9
# After: Street number
# Before: Street number 9
# After: Street number
# Before: Street number 9
# After: Street number
# Before: Street number 9
# After: Street number
# Before: Street number 9
# After: Street number
# Before: NEAR OLD VETERINARY CAMPUS
# After: NEAR OLD VETERINARY CAMPUS
# Before: Old Bombay Highway
# After: Old Bombay Highway
# Before: Vivekananda Nagar Lane 4
#
# After: Vivekananda Nagar Lane
# Before: Vidyuth Nagar
# After: Vidyuth Nagar
# Before: Tilak Road
# After: Tilak Road
# Before: Chinthalkunta Road
# After: Chinthalkunta Road
# Before: snehapuri colony
# After: snehapuri Colony
# Before: Ananda Nagar Colony
# After: Ananda Nagar Colony
# Before: Tilak Road
# After: Tilak Road
# Before: Alkapuri
# After: Alkapuri
# Before: Nishat Bagh Colony Road, Begumpet
# After: Nishat Bagh Colony Road Begumpet
# Before: Ananda Nagar
# After: Ananda Nagar
# Before: chinthalkumta,lb Nagar Hyderabad
# After: chinthalkumtalb Nagar Hyderabad
# Before: Road No 5
# After: Road No
# Before: Road No 5
# After: Road No
# Before: Street 10-D
# After: Street 10-D
# Before: Street 10-D
# After: Street 10-D
# Before: Street 10-D
# After: Street 10-D
# Before: Street 10-D
# After: Street 10-D
# Before: lb nagar
# After: lb Nagar
# Before: Alkapuri
# After: Alkapuri
# Before: new shantinagar colony
# After: new shantinagar Colony
# Before: kamineni junction
# After: kamineni junction
# Before: Musheerabad Main Road
# After: Musheerabad Main Road
# Before: vijayapuri colony rd
# After: vijayapuri colony rd
# Before: subhadra nagar
# After: subhadra Nagar
# Before: Ramalayam Street
# After: Ramalayam Street
# Before: Harinagar Main Road,  Marinatha Church
# After: Harinagar Main Road  Marinatha Church
# Before: Golconda Road
# After: Golconda Road
# Before: hakeempet road
# After: hakeempet Road
# Before: Quena Square, Banjara Hills Road No. 1
# After: Quena Square, Banjara Hills Road No.
# Before: Sardar Patel Rd
# After: Sardar Patel Road
# Before: Sardar Patel Rd
# After: Sardar Patel Road
# Before: Sardar Patel Rd
# After: Sardar Patel Road
# Before: uppuguda
# After: uppuguda
# Before: Uppuguda
# After: Uppuguda
# Before: ISB Road
# After: ISB Road
# Before: HCU main road
# After: HCU main Road
# Before: HCU main road (University of Hyderabad)
# After: HCU main road (University of Hyderabad)
# Before: Road No. 12
# After: Road No.
# Before: Old Bombay Road
# After: Old Bombay Road
# Before: Shilpa Nagar, Gowrinathapuram
# After: Shilpa Nagar Gowrinathapuram
# Before: Wipro SEZ Parking Route
# After: Wipro SEZ Parking Route
# Before: Prenderghast Road
# After: Prenderghast Road
# Before: manage rd
# After: manage rd
# Before: manage rd
# After: manage rd
# Before: MANAGE road
# After: MANAGE Road
# Before: MANAGE Administrative Building Road
# After: MANAGE Administrative Building Road
# Before: MANAGE Administrative Building Road
# After: MANAGE Administrative Building Road
# Before: Balanagar Cross Road
# After: Balanagar Cross Road
# Before: R.C.Puram
# After: R.C.Puram
# Before: R.C.Puram
# After: R.C.Puram
# Before: gandhi nagar road
# After: gandhi nagar Road
# Before: Plot 103-105, KPBH 5th Phase
# After: Plot 103-105 KPBH 5th Phase
# Before: Plot No: 103 to 105, KPHB, 5th Phase
# After: Plot No: 103 to 105 KPHB 5th Phase
# Before: 12
# After:
# Before: Road No 3
# After: Road No
# Before: Road No 15
# After: Road No
# Before: Road No 15
# After: Road No
# Before: Borabanda Mothinagar road
# After: Borabanda Mothinagar Road
# Before: Borabanda Mothinagar road
# After: Borabanda Mothinagar Road
# Before: Road No 10 Bandari Layout
# After: Road No 10 Bandari Layout
# Before: 20
# After:
# Before: Rajarejwari Nagar, Konapur
# After: Rajarejwari Nagar Konapur
# Before: Pochamma Bagh
# After: Pochamma Bagh
# Before: Road No 3
# After: Road No
# Before: Dhoolpet Road
# After: Dhoolpet Road
# Before: Lower Dhoolpet road
# After: Lower Dhoolpet Road
# Before: Musheerabad Main Road
# After: Musheerabad Main Road
# Before: Musheerabad Main Road
# After: Musheerabad Main Road
# Before: Ragala Enclave road
# After: Ragala Enclave Road
# Before: Defence Colony
# After: Defence Colony
# Before: Sai Baba Nagar
# After: Sai Baba Nagar
# Before: Don Bosco Nagar
# After: Don Bosco Nagar
# Before: Kismatpur
# After: Kismatpur
# Before: HILL TOP QUARTERS
# After: HILL TOP QUARTERS
# Before: kismatpur
# After: kismatpur
# Before: Kismatpur
# After: Kismatpur
# Before: Kismatpur
# After: Kismatpur

# %% [markdown]
# POSTAL CODES

# %% [markdown]
# In the first iteration of postal code Auditing ,I found and updated the postal codes which has white space characters present in postal codes and also the range of postal codes that lie in the city limits

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

pin_outside = []
pin_inside = []
i = 0
white_space=re.compile(r'\S+\s+\S+')
for event , elem in ET.iterparse(osm_file):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if tag.attrib['k'] == "postal_code" or tag.attrib['k'] == "addr:postcode":
                if white_space.search(tag.attrib['v']):
                    i=i+1
                    continue
                elif int(tag.attrib['v'].strip())<500010 or int(tag.attrib['v'].strip())>500070:
                     pin_outside.append(tag.attrib['v'])
                        
                elif int(tag.attrib['v'].strip())>500010 or int(tag.attrib['v'].strip())<500070:
                     pin_inside.append(tag.attrib['v'])
                        
print "Number of postal codes wrongly entered :",i                    
print "Number of Postal codes which line outside the city : ",len(pin_outside)
print "Number of Postal codes which belong to city limits 500010-500070 :",len(pin_inside)
# Out:
# Number of postal codes wrongly entered : 5
# Number of Postal codes which line outside the city :  278
# Number of Postal codes which belong to city limits 500010-500070 : 357

# %% [markdown]
# In the second iteration,I found that some Postal codes were entered as string

# %%
white_space=re.compile(r'\S+\s+\S+')
COLON= re.compile(r'^([a-z]|_)+:')
def update_pincode(pincode):
    if white_space.search(pincode):
        x=pincode.replace(" ","") 
        return x 
    elif tag.attrib['v']=='Vikrampuri':
         return None
    elif COLON.search(pincode):
         return None
    elif int(pincode)<500010 or int(pincode)>500070:
         return None
    else:
        return pincode

# %% [markdown]
# and In third iteration I found some postal codes wrongly entered as a string and colon “ : ” present in the string with help of regular expression(“^([a-z]|_)+:”) I’ve updated the both postal codes as None.

# %%
for event, elem in ET.iterparse(osm_file):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if tag.attrib['k'] == "postal_code" or tag.attrib['k'] == "addr:postcode":
                print "Before :",tag.attrib['v']
                print "After :",update_pincode(tag.attrib['v'])
# Out:
# Before : 509218
# After : None
# Before : 501506
# After : None
# Before : 500659
# After : None
# Before : 500008
# After : None
# Before : 500013
# After : 500013
# Before : 500015
# After : 500015
# Before : 500038
# After : 500038
# Before : 502319
# After : None
# Before : 501503
# After : None
# Before : 500015
# After : 500015
# Before : 500013
# After : 500013
# Before : 500011
# After : 500011
# Before : 500084
# After : None
# Before : 500015
# After : 500015
# Before : 500015
# After : 500015
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 50004
# After : None
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500044
# After : 500044
# Before : 500081
# After : None
# Before : Hyderabad – 500032
# After : Hyderabad–500032
# Before : 500019
# After : 500019
# Before : 500034
# After : 500034
# Before : 500072
# After : None
# Before : 500009
# After : None
# Before : 500052
# After : 500052
# Before : 500084
# After : None
# Before : 500081
# After : None
# Before : 500034
# After : 500034
# Before : 500082
# After : None
# Before : 500034
# After : 500034
# Before : 500090
# After : None
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 50003
# After : None
# Before : 500081
# After : None
# Before : 500081
# After : None
# Before : 500003
# After : None
# Before : 500038
# After : 500038
# Before : 500007
# After : None
# Before : 500007
# After : None
# Before : 500084
# After : None
# Before : 500068
# After : 500068
# Before : 500074
# After : None
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500 095
# After : 500095
# Before : 500082
# After : None
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500023
# After : 500023
# Before : 500062
# After : 500062
# Before : 500062
# After : 500062
# Before : 500062
# After : 500062
# Before : 500062
# After : 500062
# Before : 500084
# After : None
# Before : 500062
# After : 500062
# Before : 500020
# After : 500020
# Before : 500072
# After : None
# Before : 500072
# After : None
# Before : 500044
# After : 500044
# Before : 500072
# After : None
# Before : 500072
# After : None
# Before : 500010
# After : 500010
# Before : 500010
# After : 500010
# Before : 500010
# After : 500010
# Before : 500067
# After : 500067
# Before : 500067
# After : 500067
# Before : 500067
# After : 500067
# Before : 500067
# After : 500067
# Before : 500067
# After : 500067
# Before : 500084
# After : None
# Before : 500028
# After : 500028
# Before : 500028
# After : 500028
# Before : 500028
# After : 500028
# Before : 500028
# After : 500028
# Before : 500028
# After : 500028
# Before : 500028
# After : 500028
# Before : 500028
# After : 500028
# Before : 500028
# After : 500028
# Before : 500028
# After : 500028
# Before : 500028
# After : 500028
# Before : 500028
# After : 500028
# Before : 500072
# After : None
# Before : 500039
# After : 500039
# Before : 500081
# After : None
# Before : 500028
# After : 500028
# Before : 500080
# After : None
# Before : 500081
# After : None
# Before : 500032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500081
# After : None
# Before : 500018
# After : 500018
# Before : 500032
# After : 500032
# Before : 500081
# After : None
# Before : 500081
# After : None
# Before : 500081
# After : None
# Before : 500081
# After : None
# Before : 500 081
# After : 500081
# Before : 500073
# After : None
# Before : 500072
# After : None
# Before : 500081
# After : None
# Before : 500049
# After : 500049
# Before : 500072
# After : None
# Before : 500029
# After : 500029
# Before : 400056
# After : None
# Before : 50046
# After : None
# Before : 500032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500055
# After : 500055
# Before : 500055
# After : 500055
# Before : 500055
# After : 500055
# Before : 500055
# After : 500055
# Before : 500038
# After : 500038
# Before : 500038
# After : 500038
# Before : 500038
# After : 500038
# Before : 500038
# After : 500038
# Before : 500016
# After : 500016
# Before : 500001
# After : None
# Before : 500064
# After : 500064
# Before : 500007
# After : None
# Before : 500036
# After : 500036
# Before : 500001
# After : None
# Before : 50
# After : None
# Before : 500032
# After : 500032
# Before : 500013
# After : 500013
# Before : 500013
# After : 500013
# Before : 5000000
# After : None
# Before : 500090
# After : None
# Before : 500035
# After : 500035
# Before : 500035
# After : 500035
# Before : 500035
# After : 500035
# Before : 500070
# After : 500070
# Before : 500070
# After : 500070
# Before : 500033
# After : 500033
# Before : 500034
# After : 500034
# Before : 500085
# After : None
# Before : 500081
# After : None
# Before : 500029
# After : 500029
# Before : 500055
# After : 500055
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500018
# After : 500018
# Before : 500030
# After : 500030
# Before : 500030
# After : 500030
# Before : 500081
# After : None
# Before : 500035
# After : 500035
# Before : 500003
# After : None
# Before : 500107
# After : None
# Before : 500042
# After : 500042
# Before : 500035
# After : 500035
# Before : 500072
# After : None
# Before : 500033
# After : 500033
# Before : 500035
# After : 500035
# Before : 500003
# After : None
# Before : 500100
# After : None
# Before : 500014
# After : 500014
# Before : 500028
# After : 500028
# Before : 500062
# After : 500062
# Before : 500072
# After : None
# Before : 500002
# After : None
# Before : 500075
# After : None
# Before : 500072
# After : None
# Before : 500016
# After : 500016
# Before : 500082
# After : None
# Before : 500016
# After : 500016
# Before : 500082
# After : None
# Before : 500027
# After : 500027
# Before : 500027
# After : 500027
# Before : 500057
# After : 500057
# Before : 500082
# After : None
# Before : 500033
# After : 500033
# Before : 500017
# After : 500017
# Before : 500068
# After : 500068
# Before : 500034
# After : 500034
# Before : 500090
# After : None
# Before : 500053
# After : 500053
# Before : 500003
# After : None
# Before : 500062
# After : 500062
# Before : 500008
# After : None
# Before : 500008
# After : None
# Before : 500008
# After : None
# Before : 500008
# After : None
# Before : 500008
# After : None
# Before : 500062
# After : 500062
# Before : 500013
# After : 500013
# Before : 500050
# After : 500050
# Before : 50008
# After : None
# Before : 500057
# After : 500057
# Before : 500015
# After : 500015
# Before : 500081
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500081
# After : None
# Before : 500034
# After : 500034
# Before : 500033
# After : 500033
# Before : 500033
# After : 500033
# Before : 500033
# After : 500033
# Before : 500033
# After : 500033
# Before : 500033
# After : 500033
# Before : 500034
# After : 500034
# Before : 500034
# After : 500034
# Before : 500081
# After : None
# Before : 500034
# After : 500034
# Before : 500034
# After : 500034
# Before : 500081
# After : None
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500034
# After : 500034
# Before : 500016
# After : 500016
# Before : 500048
# After : 500048
# Before : 500012
# After : 500012
# Before : 500001
# After : None
# Before : 500081
# After : None
# Before : 500081
# After : None
# Before : 500081
# After : None
# Before : 500081
# After : None
# Before : 500081
# After : None
# Before : 500037
# After : 500037
# Before : 500018
# After : 500018
# Before : 500032
# After : 500032
# Before : 500037
# After : 500037
# Before : 501218
# After : None
# Before : 500037
# After : 500037
# Before : 500032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500082
# After : None
# Before : 500034
# After : 500034
# Before : 500068
# After : 500068
# Before : 500037
# After : 500037
# Before : 500016
# After : 500016
# Before : 500016
# After : 500016
# Before : 500034
# After : 500034
# Before : 500003
# After : None
# Before : 500034
# After : 500034
# Before : 500063
# After : 500063
# Before : 500003
# After : None
# Before : 500034
# After : 500034
# Before : 500016
# After : 500016
# Before : 500016
# After : 500016
# Before : 500034
# After : 500034
# Before : 500082
# After : None
# Before : 500033
# After : 500033
# Before : 500034
# After : 500034
# Before : 500034
# After : 500034
# Before : 500016
# After : 500016
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500076
# After : None
# Before : 500083
# After : None
# Before : 502032
# After : None
# Before : 500074
# After : None
# Before : 500057
# After : 500057
# Before : 34500034
# After : None
# Before : 500084
# After : None
# Before : 500084
# After : None
# Before : 500064
# After : 500064
# Before : 502032
# After : None
# Before : 500084
# After : None
# Before : 500033
# After : 500033
# Before : 500072
# After : None
# Before : 500068
# After : 500068
# Before : 500076
# After : None
# Before : 500046
# After : 500046
# Before : 500096
# After : None
# Before : 500046
# After : 500046
# Before : 500049
# After : 500049
# Before : 500029
# After : 500029
# Before : 500029
# After : 500029
# Before : 500032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500081
# After : None
# Before : 500074
# After : None
# Before : 500096
# After : None
# Before : 500096
# After : None
# Before : 500033
# After : 500033
# Before : 500026
# After : 500026
# Before : 500008
# After : None
# Before : 500008
# After : None
# Before : 500001
# After : None
# Before : 500001
# After : None
# Before : 500032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500034
# After : 500034
# Before : 500055
# After : 500055
# Before : 500006
# After : None
# Before : 500098
# After : None
# Before : 500026
# After : 500026
# Before : 500053
# After : 500053
# Before : 500045
# After : 500045
# Before : 500045
# After : 500045
# Before : 500070
# After : 500070
# Before : 500081
# After : None
# Before : 500045
# After : 500045
# Before : 500045
# After : 500045
# Before : 500039
# After : 500039
# Before : 500034
# After : 500034
# Before : 500038
# After : 500038
# Before : 500081
# After : None
# Before : 500081
# After : None
# Before : 500 081
# After : 500081
# Before : 500081
# After : None
# Before : 500081
# After : None
# Before : 500075
# After : None
# Before : 500075
# After : None
# Before : 5021377
# After : None
# Before : 500082
# After : None
# Before : 500081
# After : None
# Before : 500034
# After : 500034
# Before : 500081
# After : None
# Before : 500035
# After : 500035
# Before : 500078
# After : None
# Before : 500068
# After : 500068
# Before : 500084
# After : None
# Before : 500033
# After : 500033
# Before : 500 032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500089
# After : None
# Before : 500068
# After : 500068
# Before : 500018
# After : 500018
# Before : 500038
# After : 500038
# Before : 500038
# After : 500038
# Before : 500007
# After : None
# Before : 500007
# After : None
# Before : 500007
# After : None
# Before : 500007
# After : None
# Before : 500007
# After : None
# Before : 500007
# After : None
# Before : 500007
# After : None
# Before : 500007
# After : None
# Before : 500039
# After : 500039
# Before : 500082
# After : None
# Before : 500038
# After : 500038
# Before : 500003
# After : None
# Before : 502319
# After : None
# Before : 500039
# After : 500039
# Before : 500062
# After : 500062
# Before : 500067
# After : 500067
# Before : 500055
# After : 500055
# Before : 500032
# After : 500032
# Before : 500072
# After : None
# Before : 500060
# After : 500060
# Before : 500032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500049
# After : 500049
# Before : 500028
# After : 500028
# Before : 500055
# After : 500055
# Before : 500055
# After : 500055
# Before : 500085
# After : None
# Before : 500085
# After : None
# Before : 500045
# After : 500045
# Before : 500050
# After : 500050
# Before : 500050
# After : 500050
# Before : 500050
# After : 500050
# Before : 500003
# After : None
# Before : 500003
# After : None
# Before : 500003
# After : None
# Before : 500003
# After : None
# Before : 500028
# After : 500028
# Before : 500032
# After : 500032
# Before : 500081
# After : None
# Before : 996544
# After : None
# Before : 500081
# After : None
# Before : 500029
# After : 500029
# Before : 500029
# After : 500029
# Before : 500029
# After : 500029
# Before : 500029
# After : 500029
# Before : 500029
# After : 500029
# Before : 500072
# After : None
# Before : 500085
# After : None
# Before : 500030
# After : 500030
# Before : 500050
# After : 500050
# Before : 500050
# After : 500050
# Before : 500050
# After : 500050
# Before : 500029
# After : 500029
# Before : 500034
# After : 500034
# Before : 500016
# After : 500016
# Before : 500085
# After : None
# Before : 500013
# After : 500013
# Before : 500013
# After : 500013
# Before : 500013
# After : 500013
# Before : 500013
# After : 500013
# Before : 500062
# After : 500062
# Before : 500055
# After : 500055
# Before : 500090
# After : None
# Before : 500016
# After : 500016
# Before : 500003
# After : None
# Before : 500049
# After : 500049
# Before : 500038
# After : 500038
# Before : 500081
# After : None
# Before : 500049
# After : 500049
# Before : 500072
# After : None
# Before : 500090
# After : None
# Before : 500081
# After : None
# Before : 500073
# After : None
# Before : 500073
# After : None
# Before : 500072
# After : None
# Before : 500036
# After : 500036
# Before : 500007
# After : None
# Before : 500033
# After : 500033
# Before : 500044
# After : 500044
# Before : 500064
# After : 500064
# Before : 500084
# After : None
# Before : 500084
# After : None
# Before : 500081
# After : None
# Before : 500026
# After : 500026
# Before : 500084
# After : None
# Before : 500032
# After : 500032
# Before : 500032
# After : 500032
# Before : 500072
# After : None
# Before : 500074
# After : None
# Before : 500062
# After : 500062
# Before : 500027
# After : 500027
# Before : 500090
# After : None
# Before : 500005
# After : None
# Before : 500015
# After : 500015
# Before : 500060
# After : 500060
# Before : 500072
# After : None
# Before : 500070
# After : 500070
# Before : 500070
# After : 500070
# Before : 500070
# After : 500070
# Before : 500070
# After : 500070
# Before : 500015
# After : 500015
# Before : 500055
# After : 500055
# Before : 500072
# After : None
# Before : 500072
# After : None
# Before : 500062
# After : 500062
# Before : 500046
# After : 500046
# Before : 500046
# After : 500046
# Before : 500019
# After : 500019
# Before : 500050
# After : 500050
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500049
# After : 500049
# Before : 500047
# After : 500047
# Before : 500047
# After : 500047
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500082
# After : None
# Before : 500045
# After : 500045
# Before : 500009
# After : None
# Before : 500034
# After : 500034
# Before : 500025
# After : 500025
# Before : 500045
# After : 500045
# Before : 500033
# After : 500033
# Before : 500016
# After : 500016
# Before : 500089
# After : None
# Before : 500082
# After : None
# Before : 500081
# After : None
# Before : 500083
# After : None
# Before : 500055
# After : 500055
# Before : 500016
# After : 500016
# Before : 500003
# After : None
# Before : 500003
# After : None
# Before : 500003
# After : None
# Before : 500003
# After : None
# Before : 500013
# After : 500013
# Before : 500082
# After : None
# Before : 500038
# After : 500038
# Before : 500082
# After : None
# Before : 500017
# After : 500017
# Before : 500002
# After : None
# Before : 500002
# After : None
# Before : 500016
# After : 500016
# Before : 500036
# After : 500036
# Before : 500089
# After : None
# Before : 500001
# After : None
# Before : 500092
# After : None
# Before : 500057
# After : 500057
# Before : 500028
# After : 500028
# Before : 500018
# After : 500018
# Before : 500028
# After : 500028
# Before : 500017
# After : 500017
# Before : 500086
# After : None
# Before : 500028
# After : 500028
# Before : 500003
# After : None
# Before : 500086
# After : None
# Before : 500068
# After : 500068
# Before : 500068
# After : 500068
# Before : 500098
# After : None
# Before : 500068
# After : 500068
# Before : 500098
# After : None
# Before : 500068
# After : 500068
# Before : 500068
# After : 500068
# Before : 500068
# After : 500068
# Before : 500068
# After : 500068
# Before : 500068
# After : 500068
# Before : 500068
# After : 500068
# Before : 500068
# After : 500068
# Before : 500068
# After : 500068
# Before : 500030
# After : 500030
# Before : 500060
# After : 500060
# Before : 500001
# After : None
# Before : 500035
# After : 500035
# Before : 500016
# After : 500016
# Before : 500004
# After : None
# Before : 500008
# After : None
# Before : 500008
# After : None
# Before : 500008
# After : None
# Before : 500008
# After : None
# Before : 500074
# After : None
# Before : 500035
# After : 500035
# Before : 500039
# After : 500039
# Before : 500020
# After : 500020
# Before : 500070
# After : 500070
# Before : 500020
# After : 500020
# Before : 500028
# After : 500028
# Before : 500008
# After : None
# Before : 500083
# After : None
# Before : 500046
# After : 500046
# Before : 500003
# After : None
# Before : 500003
# After : None
# Before : 500003
# After : None
# Before : 500006
# After : None
# Before : 500038
# After : 500038
# Before : 500046
# After : 500046
# Before : 500046
# After : 500046
# Before : 500046
# After : 500046
# Before : 500034
# After : 500034
# Before : 500083
# After : None
# Before : 500003
# After : None
# Before : 500030
# After : 500030
# Before : 500030
# After : 500030
# Before : 500030
# After : 500030
# Before : 500030
# After : 500030
# Before : 500030
# After : 500030
# Before : 500036
# After : 500036
# Before : 502032
# After : None
# Before : 502032
# After : None
# Before : 500080
# After : None
# Before : 500072
# After : None
# Before : 500072
# After : None
# Before : 500072
# After : None
# Before : 500033
# After : 500033
# Before : 500005
# After : None
# Before : 500018
# After : 500018
# Before : 500018
# After : 500018
# Before : 500090
# After : None
# Before : 500049
# After : 500049
# Before : 500084
# After : None
# Before : 500060
# After : 500060
# Before : 500034
# After : 500034
# Before : 500006
# After : None
# Before : 500020
# After : 500020
# Before : 500020
# After : 500020
# Before : 500070
# After : 500070
# Before : 500090
# After : None
# Before : 500086
# After : None
# Before : 500086
# After : None
# Before : 500086
# After : None
# Before : 500086
# After : None
# Before : 500086
# After : None
# Before : 500086
# After : None
# Before : 500086
# After : None
# Before : 500086
# After : None
# Before : 500086
# After : None
# Before : 500045
# After : 500045
# Before : 500086
# After : None
# Before : 500086
# After : None
# Before : 500086
# After : None

# %% [markdown]
# After auditing is complete the next step is to prepare the data to be inserted into a SQL database.
# To do so we will parse the elements in the OSM XML file, transforming them from document format to
# tabular format, thus making it possible to write to .csv files.  These csv files can then easily be
# imported to a SQL database as tables.

# %%
import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET

import cerberus

import schema

OSM_PATH = "hyderabad_india.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements
   
    # YOUR CODE HERE
    if element.tag == 'node': 
        for k in element.attrib: 
            if k in NODE_FIELDS: 
                node_attribs[k]=element.attrib[k] 
        for y in element: 
            if y.tag=='tag': 
                node_tags = {}
                # tag k = 'addr:street' v = ' kormangala'
                # tag k = 'hourse ' v = 'asome'
                node_tags['id']=element.attrib['id'] 
                if LOWER_COLON.match(y.attrib['k']): 
                    
                    node_tags['key']=y.attrib['k'].split(":",1)[1] 
                    node_tags['type']=y.attrib['k'].split(":",1)[0] 
                else: 
                    node_tags['key'] = y.attrib['k']
                    node_tags['type'] = 'regular'
                    
                if y.attrib["k"] == 'addr:street':
                    if update_street_name(y.attrib["v"] , mapping):
                        node_tags["value"] = update_street_name(y.attrib["v"] , mapping)
                    else:
                        continue
                
                elif y.attrib["k"] == "addr:postcode":
                    if update_pincode(y.attrib["v"]):
                        node_tags["value"] = update_pincode(y.attrib["v"])
                    else:
                        continue
                else:
                    node_tags["value"] = y.attrib["v"]

                tags.append(node_tags)
                      
        return {'node': node_attribs, 'node_tags': tags} 
                
             

        
    elif element.tag == 'way': 
            for x in element.attrib: 
                if x in WAY_FIELDS: 
                    way_attribs[x]=element.attrib[x] 
            i=0 
            for q in element.iter("nd"): 
               
                way_nodes.append({'id':element.attrib['id'],'node_id':q.attrib['ref'],'position':i}) 
                i+=1 
            for y in element: 
                if y.tag=='tag': 
                    node_tags = {}
                    node_tags['id']=element.attrib['id']
                    if LOWER_COLON.match(y.attrib['k']): 
                         
                        node_tags['key']=y.attrib['k'].split(":",1)[1] 
                        node_tags['type']=y.attrib['k'].split(":",1)[0] 
                    else: 
                        node_tags['key'] = y.attrib['k']
                        node_tags['type'] = 'regular'
                    
                    if y.attrib["k"] == 'addr:street':
                        if update_street_name(y.attrib["v"] , mapping):
                            node_tags["value"] = update_street_name(y.attrib["v"] , mapping)
                        else:
                            continue
                    
                    elif y.attrib["k"] == "addr:postcode":
                        if update_pincode(y.attrib["v"]):
                            node_tags["value"] = update_pincode(y.attrib["v"])
                        else:
                            continue

                       
                    else:
                         node_tags["value"] = y.attrib["v"]
                        
                    tags.append(node_tags)
                   
            return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}       
    

# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                    if element.tag == 'node':
                        nodes_writer.writerow(el['node'])
                        node_tags_writer.writerows(el['node_tags'])
                    elif element.tag == 'way':
                        ways_writer.writerow(el['way'])
                        way_nodes_writer.writerows(el['way_nodes'])
                        way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=True)

# %% [markdown]
# Importing sqlite so that we can use the csv files in the database

# %%
import sqlite3
import pandas as pd
import numpy as np
from pprint import pprint
from time import time
import csv
#creating a database
sql_file = "hyderabad_india.db"

conn = sqlite3.connect(sql_file)
cur = conn.cursor()
print (type(cur))
# Out:
# <type 'sqlite3.Cursor'>

# %%
#creating the table nodes
cur.execute('Drop table nodes;')
cur.execute("CREATE TABLE nodes(id,lat,lon,user,uid,version,changeset,timestamp);")
with open ('nodes.csv' , 'rb') as f:
    dic = csv.DictReader(f)
    to_db = [(i['id'],i['lat'],i['lon'],i['user'].decode("utf-8"),i['uid'].decode("utf-8"),i['version'],i['changeset'],i['timestamp'])
            for i in dic]
cur.executemany("INSERT INTO nodes(id,lat,lon,user,uid,version,changeset,timestamp) VALUES (?,?,?,?,?,?,?,?);" , to_db)
conn.commit()

# %%
##creating the table ways
cur.execute('Drop table if exists ways;')
cur.execute("CREATE TABLE ways(id,user,uid,version,changeset,timestamp);")
with open ('ways.csv' , 'rb') as f:
    dic = csv.DictReader(f)
    to_db = [(i['id'],i['user'].decode("utf-8"),i['uid'].decode("utf-8"),i['version'],i['changeset'],i['timestamp'])
            for i in dic]
cur.executemany("INSERT INTO ways(id,user,uid,version,changeset,timestamp) VALUES (?,?,?,?,?,?);" , to_db)
conn.commit()

# %%
#creating the table nodes_tags
cur.execute('Drop table if exists nodes_tags;')
cur.execute("CREATE TABLE nodes_tags(id,key,value,type);")
with open ('nodes_tags.csv' , 'rb') as f:
    dic = csv.DictReader(f)
    to_db = [(i['id'].decode("utf-8"),i['key'].decode("utf-8"),i['value'].decode("utf-8"),i['type'].decode("utf-8"))
            for i in dic]
cur.executemany("INSERT INTO nodes_tags(id,key,value,type) VALUES (?,?,?,?);" , to_db)
conn.commit()

# %%
#creating the table ways_nodes
cur.execute('Drop table if exists ways_nodes;')
cur.execute("CREATE TABLE ways_nodes(id,node_id,position);")
with open ('ways_nodes.csv' , 'rb') as f:
    dic = csv.DictReader(f)
    to_db = [(i['id'],i['node_id'],i['position'])
            for i in dic]
cur.executemany("INSERT INTO ways_nodes(id,node_id,position) VALUES (?,?,?);" , to_db)
conn.commit()

# %%
#creating the table ways_tags
cur.execute('Drop table if exists ways_tags;')
cur.execute("CREATE TABLE ways_tags(id,key,value,type);")
with open ('ways_tags.csv' , 'rb') as f:
    dic = csv.DictReader(f)
    to_db = [(i['id'].decode("utf-8"),i['key'].decode("utf-8"),i['value'].decode("utf-8"),i['type'].decode("utf-8"))
            for i in dic]
cur.executemany("INSERT INTO ways_tags(id,key,value,type) VALUES (?,?,?,?);" , to_db)
conn.commit()

# %%
#number of nodes

QUERY ='''SELECT count(*)as num from nodes'''
cur.execute(QUERY)
all_nodes = cur.fetchall()
df = pd.DataFrame(all_nodes)
print df
# Out:
#          0
# 0  3227936

# %% [markdown]
# There are 3227936 nodes.

# %%
#number of ways tags
QUERY ='''SELECT count(*)as num from ways'''
cur.execute(QUERY)
all_ways = cur.fetchall()
df = pd.DataFrame(all_ways)
print df
# Out:
#         0
# 0  770099

# %% [markdown]
# There are 770099 way tags.

# %%
QUERY = '''SELECT DISTINCT(user) 
FROM (SELECT user from nodes UNION SELECT user from ways)
GROUP BY user
ORDER BY count(user) 
DESC
;

'''
cur.execute(QUERY)
top_unique_users = cur.fetchall()
df = pd.DataFrame(top_unique_users)
print "The number of distinct users:" , len(df)
# Out:
# The number of distinct users: 1003

# %%
# number of amenities
QUERY =''' SELECT value, COUNT(*) as num 
FROM (select value , key from nodes_tags UNION ALL select value, key from ways_tags)
WHERE key='amenity'
GROUP BY value
ORDER BY num DESC
;
'''
cur.execute(QUERY)
all_amenities = cur.fetchall()
df = pd.DataFrame(all_amenities)
print "total number of amenities:", len(df)
# Out:
# total number of amenities: 76

# %%
#top 10 amenities
QUERY =''' SELECT value, COUNT(*) as num 
FROM (select value , key from nodes_tags UNION ALL select value, key from ways_tags)
WHERE key='amenity'
GROUP BY value
ORDER BY num DESC
limit 10
;
'''
cur.execute(QUERY)
all_amenities = cur.fetchall()
df = pd.DataFrame(all_amenities)
print df
# Out:
#                   0    1
# 0  place_of_worship  387
# 1        restaurant  282
# 2               atm  264
# 3              bank  260
# 4            school  196
# 5              fuel  167
# 6          hospital  161
# 7           parking  117
# 8          pharmacy  114
# 9              cafe  101

# %% [markdown]
# place of worship tops the list with 387 followed by restaurant with 282

# %%
#number of users
QUERY =''' SELECT user,count(user) from( select user from nodes UNION ALL select user from ways)
GROUP BY user
ORDER BY count(user)
DESC;
'''
cur.execute(QUERY)
all_unique_users = cur.fetchall()
import pandas as pd
df = pd. DataFrame(all_unique_users)
print df[1].describe()
print('\n')
print "Total users:" , df[1].sum()
# Out:
# count      1003.00000
# mean       3986.07677
# std       16866.43680
# min           1.00000
# 25%           2.00000
# 50%           7.00000
# 75%          51.00000
# max      144934.00000
# Name: 1, dtype: float64
#
#
# Total users: 3998035

# %% [markdown]
# The total number of users are 3998035
# The average number of posts are 3986

# %%
#top 5 cuisisnes
QUERY =''' SELECT value, COUNT(*) as num 
FROM (select value , key from nodes_tags UNION ALL select value, key from ways_tags)
WHERE key='cuisine'
GROUP BY value
ORDER BY num DESC
LIMIT 5;

'''
cur.execute(QUERY)
all_cuisines = cur.fetchall()
df = pd.DataFrame(all_cuisines)
print df
# Out:
#              0   1
# 0       indian  41
# 1     regional  27
# 2  coffee_shop  18
# 3        pizza  14
# 4      chinese  10

# %%
#number of places in hyderabad
QUERY ='''SELECT tags.value, COUNT(*) as count 
FROM (SELECT * FROM nodes_tags UNION ALL 
      SELECT * FROM ways_tags) tags
WHERE tags.key LIKE '%city'
GROUP BY tags.value
ORDER BY count DESC;'''

cur.execute(QUERY)
all_cITIES = cur.fetchall()
df = pd.DataFrame(all_cITIES)
print "number of places :", len(df)
# Out:
# number of places : 56

# %%
#most followed religion
QUERY = '''SELECT nodes_tags.value, COUNT(*) as num
FROM nodes_tags 
    JOIN (SELECT DISTINCT(id) FROM nodes_tags WHERE value='place_of_worship') i
    ON nodes_tags.id=i.id
WHERE nodes_tags.key='religion'
GROUP BY nodes_tags.value
ORDER BY num DESC
LIMIT 1;'''
cur.execute(QUERY)
religion = cur.fetchall()
df = pd.DataFrame(religion)
print df
# Out:
#        0    1
# 0  hindu  118

# %% [markdown]
# Advantages and Disadvantages :
# The main advantage is that Open Street Map data is open-source and therefore free to use. This means anyone can use the data to create their own maps (and then use services like Map Box to generate and host customised map tiles). This means the developer doesn't have to work within Google's constraints.
# The only imaginable downside to me is quality. Get me right, 99% is the good stuff, but as all crowd sourced data it's hard to maintain consistent quality control. Of course is free to alter and complete the data, but there's no guarantees as there would with a company behind it.

# %% [markdown]
# Conclusion:
# After series of iterations in Auditing process, I believe that the data has been cleaned precisely and analysed well in exploration phase .
